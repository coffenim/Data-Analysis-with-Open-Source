# %% [markdown]
# <a href="https://colab.research.google.com/github/coffenim/Data-Analysis-with-Open-Source/blob/main/251118%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    number = int(input('숫자를 입력하세요: '))
    result = 10 / number
except ValueError:
    print('유효한 숫자를 입력해야 합니다.')
except ZeroDivisionError:
    print('0으로 나눌수 없습니다.')
print(f'결과: {result}')
# Out:
# 숫자를 입력하세요: 2
# 결과: 5.0

# %%
try:
    file = open('data.csv', 'r')
    content = file.read()
    print(content)
except FileNotFoundError:
    print('파일을 찾을 수 없습니다.')
finally:
    print('파일 작업 종료.')
    file.close()
# Out:
# 파일을 찾을 수 없습니다.
# 파일 작업 종료.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-205242179.py in <cell line: 0>()
#       7 finally:
#       8     print('파일 작업 종료.')
# ----> 9     file.close()
#
# NameError: name 'file' is not defined

# %%
employees = [
    {'name': '김지원', 'salary': 3700000},
    {'name': '박민준', 'salary': 7000000},
    {'name': '이서연', 'salary': 4400000},
    {'name': '정현우', 'salary': 3500000}
]
updated_employees = list(map(lambda emp: {'name': emp['name'],
                                          'salary': emp['salary'] * 1.1}, employees))
print('\n급여 인상후:')
for emp in updated_employees:
    print(f'{emp['name']}: {int(emp['salary']):,}원')
# Out:
# 급여 인상후:
# 김지원: 4,070,000원
# 박민준: 7,700,000원
# 이서연: 4,840,000원
# 정현우: 3,850,000원

# %%
import requests

url = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty'
api_key = ''
params = {
    'serviceKey' : api_key,
    'returnType' : 'json',
    'numOfRows' : '100',
    'pageNo' : '1',
    'sidoName' : '대구',
    'ver' : '1.0'
          }

response = requests.get(url, params = params)

if response.status_code == 200:
    print('API 호출 성공')
    print(response.json())
else:
    print(f'API 호출 실패: {response.status_code}')
# Out:
# API 호출 성공
# {'response': {'body': {'totalCount': 26, 'items': [{'so2Grade': '1', 'coFlag': None, 'khaiValue': '53', 'so2Value': '0.001', 'coValue': '0.3', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '28', 'khaiGrade': '2', 'pm25Value': '13', 'sidoName': '대구', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-11-18 02:00', 'coGrade': '1', 'no2Value': '0.005', 'stationName': '본동', 'pm10Grade': '2', 'o3Value': '0.023'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '51', 'so2Value': '0.002', 'coValue': '0.3', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '29', 'khaiGrade': '2', 'pm25Value': '8', 'sidoName': '대구', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-11-18 02:00', 'coGrade': '1', 'no2Value': '0.008', 'stationName': '내당동', 'pm10Grade': '2', 'o3Value': '0.024'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '52', 'so2Value': '0.002', 'coValue': '0.6', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '29', 'khaiGrade': '2', 'pm25Value': '11', 'sidoName': '대구', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-11-18 02:00', 'coGrade': '1', 'no2Value': '0.007', 'stationName': '침산동', 'pm10Grade': '2', 'o3Value': '0.024'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '47', 'so2Value': '0.002', 'coValue': '0.3', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '24', 'khaiGrade': '1', 'pm25Value': '13', 'sidoName': '대구', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-11-18 02:00', 'coGrade': '1', 'no2Value': '0.006', 'stationName': '화원읍', 'pm10Grade': '1', 'o3Value': '0.024'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '58', 'so2Value': '0.003', 'coValue': '0.8', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '31', 'khaiGrade': '2', 'pm25Value': '11', 'sidoName': '대구', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-11-18 02:00', 'coGrade': '1', 'no2Value': '0.008', 'stationName': '충혼탑', 'pm10Grade': '2', 'o3Value': '0.024'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '52', 'so2Value': '0.002', 'coValue': '0.3', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '28', 'khaiGrade': '2', 'pm25Value': '12', 'sidoName': '대구', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-11-18 02:00', 'coGrade': '1', 'no2Value': '0.006', 'stationName': '군위읍', 'pm10Grade': '2', 'o3Value': '0.026'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '53', 'so2Value': '0.002', 'coValue': '0.2', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '28', 'khaiGrade': '2', 'pm25Value': '10', 'sidoName': '대구', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-11-18 02:00', 'coGrade': '1', 'no2Value': '0.012', 'stationName': '평리동', 'pm10Grade': '2', 'o3Value': '0.022'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '43', 'so2Value': '0.002', 'coValue': '0.5', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '23', 'khaiGrade': '1', 'pm25Value': '9', 'sidoName': '대구', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-11-18 02:00', 'coGrade': '1', 'no2Value': '0.008', 'stationName': '대명동', 'pm10Grade': '1', 'o3Value': '0.026'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '48', 'so2Value': '0.002', 'coValue': '0.8', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '31', 'khaiGrade': '1', 'pm25Value': '11', 'sidoName': '대구', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-11-18 02:00', 'coGrade': '1', 'no2Value': '0.007', 'stationName': '신암동', 'pm10Grade': '1', 'o3Value': '0.026'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '54', 's ...

# %%
import pandas as pd

data = response.json() ['response']['body']['items']
df = pd.DataFrame(data)
print(df.head())

df.to_csv('air_pollution.csv', index = False, encoding = 'utf-8')
# Out:
#   so2Grade coFlag khaiValue so2Value coValue pm25Flag pm10Flag o3Grade  \
# 0        1   None        53    0.001     0.3     None     None       1
# 1        1   None        51    0.002     0.3     None     None       1
# 2        1   None        52    0.002     0.6     None     None       1
# 3        1   None        47    0.002     0.3     None     None       1
# 4        1   None        58    0.003     0.8     None     None       1
#
#   pm10Value khaiGrade  ... no2Grade o3Flag pm25Grade so2Flag  \
# 0        28         2  ...        1   None         1    None
# 1        29         2  ...        1   None         1    None
# 2        29         2  ...        1   None         1    None
# 3        24         1  ...        1   None         1    None
# 4        31         2  ...        1   None         1    None
#
#            dataTime coGrade no2Value stationName pm10Grade o3Value
# 0  2025-11-18 02:00       1    0.005          본동         2   0.023
# 1  2025-11-18 02:00       1    0.008         내당동         2   0.024
# 2  2025-11-18 02:00       1    0.007         침산동         2   0.024
# 3  2025-11-18 02:00       1    0.006         화원읍         1   0.024
# 4  2025-11-18 02:00       1    0.008         충혼탑         2   0.024
#
# [5 rows x 23 columns]
